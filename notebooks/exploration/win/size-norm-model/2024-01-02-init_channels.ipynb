# %%
import pandas as pd
import seaborn as sns
from pathlib import Path
from aging.plotting import format_plots, figure
from aging.size_norm.util import load_model_parameters

# %%
format_plots()

# %%
scan_path = Path('/n/groups/datta/win/longtogeny/size_norm/models/bottleneck_optimization_00/stage_03')

# %%
metrics = sorted(scan_path.glob('**/metrics.csv'))
results = load_model_parameters(metrics)
results = results.groupby('file').apply(lambda x: x.loc[x['epoch'] == x['epoch'].max()]).reset_index(drop=True)

# %%
results[['init_channel', 'epoch']]
# Out:
#    init_channel  epoch
# 0           256    142
# 1           512    158
# 2           128    199

# %%
sns.pointplot(data=results, x='init_channel', y='vae_val_mse')
# Out:
# <Axes: xlabel='init_channel', ylabel='vae_val_mse'>
