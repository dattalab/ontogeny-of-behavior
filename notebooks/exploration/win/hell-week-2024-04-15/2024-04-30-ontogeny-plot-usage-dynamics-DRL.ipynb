# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
keep_syllables = np.loadtxt('/n/groups/datta/win/longtogeny/data/ontogeny/version_11/to_keep_syllables_raw.txt', dtype=int)

# %%
male_df = pd.read_parquet('/n/groups/datta/win/longtogeny/data/ontogeny/version_11/ontogeny_males_raw_usage_matrix_v00.parquet').astype(float)
male_df = male_df[keep_syllables]

# %%
female_df = pd.read_parquet('/n/groups/datta/win/longtogeny/data/ontogeny/version_11/ontogeny_females_raw_usage_matrix_v00.parquet').astype(float)
female_df = female_df[keep_syllables]

# %%
avg_male = male_df.groupby('age').mean()

# %%
avg_male = avg_male - avg_male.min()
avg_male = avg_male / avg_male.max()

# %%
norm_syll_sort = (
    avg_male.rolling(5, center=True, win_type="exponential")
    .mean(tau=1.5)
    .idxmax()
    .sort_values()
    .index
)

# %%
avg_female = female_df.groupby('age').mean()

# %%
avg_female = avg_female - avg_female.min()
avg_female = avg_female / avg_female.max()

# %%
plt.imshow(avg_male[norm_syll_sort].T, aspect='auto', interpolation='none', cmap='cubehelix')
plt.colorbar()
plt.title('male ontogeny')
# Out:
# Text(0.5, 1.0, 'male ontogeny')

# %%
plt.imshow(avg_male[norm_syll_sort].query('age<32').T, aspect='auto', interpolation='none', cmap='cubehelix')
plt.colorbar()
plt.title('male ontogeny < 34')
# Out:
# Text(0.5, 1.0, 'male ontogeny < 34')

# %%
plt.imshow(avg_female[norm_syll_sort].T, aspect='auto', interpolation='none', cmap='cubehelix')
plt.colorbar()
plt.title('female ontogeny')
# Out:
# Text(0.5, 1.0, 'female ontogeny')

# %%
plt.imshow(avg_female[norm_syll_sort].query('age<32').T, aspect='auto', interpolation='none', cmap='cubehelix')
plt.colorbar()
plt.title('female ontogeny < 34')
# Out:
# Text(0.5, 1.0, 'female ontogeny < 34')

# %%
avg_female[norm_syll_sort].query('age<32')
# Out:
# syllables        36        52        42        41        53        23  \
# age
# 4          0.508206  1.000000  0.824976  1.000000  0.479451  0.280040
# 8          0.469648  0.728816  0.728410  0.374391  0.453520  0.306247
# 12         0.357843  0.716171  0.636868  0.205305  0.124589  0.471259
# 20         0.453400  0.579643  0.857353  0.079103  0.000000  0.827027
# 24         1.000000  0.846710  1.000000  0.049719  0.167292  1.000000
# 28         0.520730  0.392935  0.000000  0.142008  0.370899  0.436536
#
# syllables        49        60        62        85  ...        63        54  \
# age                                                ...
# 4          0.764879  1.000000  1.000000  1.000000  ...  0.276853  0.026845
# 8          1.000000  0.772703  0.819699  0.430191  ...  0.469596  0.180376
# 12         0.734878  0.587809  0.519379  0.238467  ...  0.682697  0.297415
# 20         0.450444  0.438287  0.558038  0.066949  ...  0.228641  0.287320
# 24         0.508221  0.307131  0.572578  0.074353  ...  0.863193  0.460105
# 28         0.343557  0.189874  0.962743  0.184046  ...  0.822462  0.455122
#
# syllables        25        61        18        7         93        5   \
# age
# 4          0.136111  0.394400  0.563473  0.339146  0.000000  0.173941
# 8          0.069758  0.433433  0.289363  0.746730  0.172638  0.172564
# 12         0.000000  0.353822  0.000000  0.603970  0.580638  0.087324
# 20         0.071934  0.000000  0.050665  0.189718  0.405088  0.045885
# 24         0.176472  0.074470  0.291179  0.000000  0.573654  0.000000
# 28         0.332752  0.551441  0.490122  0.785208  0.596043  0.633138
#
# syllables        74        50
# age
# 4          0.106891  0.098755
# 8          0.270220  0.066325
# 12         0.097440  0.000000
# 20         0.000000  0.158945
# 24         0.012798  0.265538
# 28         0.232890  0.889518
#
# [6 rows x 58 columns]

# %% [markdown]
# ## Dana ontogeny females

# %%
female_df = pd.read_parquet('/n/groups/datta/win/longtogeny/data/ontogeny/version_11/dana_ontogeny_females_raw_usage_matrix_v00.parquet').astype(float)
female_df = female_df[keep_syllables]

# %%
avg_female = female_df.groupby('age').mean()

# %%
avg_female = avg_female - avg_female.min()
avg_female = avg_female / avg_female.max()

# %%
plt.imshow(avg_female[norm_syll_sort].T, aspect='auto', interpolation='none', cmap='cubehelix')
plt.colorbar()
plt.title('female ontogeny dana')
# Out:
# Text(0.5, 1.0, 'female ontogeny dana')

# %% [markdown]
# ## Dana ontogeny males

# %%
male_df = pd.read_parquet('/n/groups/datta/win/longtogeny/data/ontogeny/version_11/dana_ontogeny_males_raw_usage_matrix_v00.parquet').astype(float)
male_df = male_df[keep_syllables]

# %%
avg_male = male_df.groupby('age').mean()

# %%
avg_male = avg_male - avg_male.min()
avg_male = avg_male / avg_male.max()

# %%
plt.imshow(avg_male[norm_syll_sort].T, aspect='auto', interpolation='none', cmap='cubehelix')
plt.colorbar()
plt.title('male ontogeny dana')
# Out:
# Text(0.5, 1.0, 'male ontogeny dana')

# %% [markdown]
# ## Male female longtogeny

# %%
female_long = pd.read_parquet('/n/groups/datta/win/longtogeny/data/ontogeny/version_11/longtogeny_v2_females_raw_usage_matrix_v00.parquet')
female_long = female_long[keep_syllables]

male_long = pd.read_parquet('/n/groups/datta/win/longtogeny/data/ontogeny/version_11/longtogeny_v2_males_raw_usage_matrix_v00.parquet')
male_long = male_long[keep_syllables]

# %%
bin_age = female_long.index.get_level_values('age') * 7 // 7
avg_usage = female_long.groupby(bin_age, observed=True).mean()

avg_usage = avg_usage - avg_usage.min()
avg_usage = avg_usage / avg_usage.max()

# %%
# female
plt.imshow(avg_usage[norm_syll_sort].T, aspect='auto', interpolation='none', cmap='cubehelix')
plt.colorbar()
plt.title('female long')
# Out:
# Text(0.5, 1.0, 'female long')

# %%
bin_age = male_long.index.get_level_values('age') * 7 // 7
avg_usage = male_long.groupby(bin_age, observed=True).mean()

avg_usage = avg_usage - avg_usage.min()
avg_usage = avg_usage / avg_usage.max()

# %%
# male
plt.imshow(avg_usage[norm_syll_sort].T, aspect='auto', interpolation='none', cmap='cubehelix')
plt.colorbar()
plt.title('male long')
# Out:
# Text(0.5, 1.0, 'male long')
