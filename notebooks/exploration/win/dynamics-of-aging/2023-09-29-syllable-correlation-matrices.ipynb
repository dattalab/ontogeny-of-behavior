# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from aging.plotting import format_plots, figure

# %%
format_plots()

# %%
def load_long_df(version=5):
    usage_mtx = pd.read_parquet(
        f"/n/groups/datta/win/longtogeny/data/ontogeny/version_{version:02d}/longtogeny_males_clean.parquet"
    )
    return usage_mtx

# %%
df = load_long_df(version=5)

# %%
corrs = df.iloc[:, :40].groupby('mouse').corr(method='spearman').fillna(0)

# %%
corrs.index.levels[0]
# Out:
# Index(['01_01', '01_02', '01_03', '01_04', '02_01', '02_02', '02_03', '02_04',
#        '03_01', '03_02', '03_03', '03_04', '04_01', '04_02', '04_03', '04_04'],
#       dtype='object', name='mouse')

# %%
g = sns.clustermap(
    df.iloc[:, :40].corr(method="spearman"),
    method="complete",
    cmap="RdBu_r",
    figsize=(2, 2),
    vmin=-1,
    vmax=1,
    cbar_kws=dict(label="Correlation (rho)"),
)

# %%
fig = figure(1.75, 1.5)
ax = sns.heatmap(
    df.iloc[:, :40].corr(method="spearman").to_numpy()[g.dendrogram_row.reordered_ind][
        :, g.dendrogram_row.reordered_ind
    ],
    vmin=-1,
    vmax=1,
    cmap="RdBu_r",
    cbar_kws=dict(label="Correlation (rho)"),
)
ax.set(aspect="equal")
# Out:
# [None]

# %%
# g = sns.clustermap(corrs.loc['01_01'], method='complete', cmap='RdBu_r', figsize=(2, 2), vmin=-1, vmax=1)

# %%
fig = figure(1.75, 1.5)
ax = sns.heatmap(
    corrs.loc["01_01"].to_numpy()[g.dendrogram_row.reordered_ind][
        :, g.dendrogram_row.reordered_ind
    ],
    vmin=-1,
    vmax=1,
    cmap="RdBu_r",
    cbar_kws=dict(label="Correlation (rho)"),
)
ax.set(aspect="equal")
# Out:
# [None]

# %%
fig = figure(1.75, 1.5)
ax = sns.heatmap(
    corrs.loc["01_02"].to_numpy()[g.dendrogram_row.reordered_ind][
        :, g.dendrogram_row.reordered_ind
    ],
    vmin=-1,
    vmax=1,
    cmap="RdBu_r",
    cbar_kws=dict(label="Correlation (rho)"),
)
ax.set(aspect="equal")
# Out:
# [None]

# %%
fig = figure(1.75, 1.5)
ax = sns.heatmap(
    corrs.loc["02_01"].to_numpy()[g.dendrogram_row.reordered_ind][
        :, g.dendrogram_row.reordered_ind
    ],
    vmin=-1,
    vmax=1,
    cmap="RdBu_r",
    cbar_kws=dict(label="Correlation (rho)"),
)
ax.set(aspect="equal")
# Out:
# [None]

# %%
arrs = []
animals = []
for a, _df in corrs.groupby('mouse'):
    arrs.append(_df.fillna(0).to_numpy().flatten())
    animals.append(a)

# %%
from scipy.spatial.distance import pdist, squareform

# %%
dists = squareform(pdist(arrs))

# %%
sns.heatmap(dists)
# Out:
# <Axes: >

# %%
fig = figure(1.75, 1.5)
ax = sns.heatmap(
    corrs.loc[animals[12]].to_numpy()[g.dendrogram_row.reordered_ind][
        :, g.dendrogram_row.reordered_ind
    ],
    vmin=-1,
    vmax=1,
    cmap="RdBu_r",
    cbar_kws=dict(label="Correlation (rho)"),
)
ax.set(aspect="equal")
# Out:
# [None]

# %%
fig = figure(1.75, 1.5)
ax = sns.heatmap(
    corrs.loc[animals[0]].to_numpy()[g.dendrogram_row.reordered_ind][
        :, g.dendrogram_row.reordered_ind
    ],
    vmin=-1,
    vmax=1,
    cmap="RdBu_r",
    cbar_kws=dict(label="Correlation (rho)"),
)
ax.set(aspect="equal")
# Out:
# [None]

# %%
fig = figure(1.75, 1.5)
ax = sns.heatmap(
    corrs.loc[animals[2]].to_numpy()[g.dendrogram_row.reordered_ind][
        :, g.dendrogram_row.reordered_ind
    ],
    vmin=-1,
    vmax=1,
    cmap="RdBu_r",
    cbar_kws=dict(label="Correlation (rho)"),
)
ax.set(aspect="equal")
# Out:
# [None]

# %%
fig = figure(1.75, 1.5)
ax = sns.heatmap(
    corrs.loc[animals[13]].to_numpy()[g.dendrogram_row.reordered_ind][
        :, g.dendrogram_row.reordered_ind
    ],
    vmin=-1,
    vmax=1,
    cmap="RdBu_r",
    cbar_kws=dict(label="Correlation (rho)"),
)
ax.set(aspect="equal")
# Out:
# [None]

# %%
for animal in animals:
    fig = figure(1.75, 1.5)
    ax = sns.heatmap(
        corrs.loc[animal].to_numpy()[g.dendrogram_row.reordered_ind][
            :, g.dendrogram_row.reordered_ind
        ],
        vmin=-1,
        vmax=1,
        cmap="RdBu_r",
        cbar_kws=dict(label="Correlation (rho)"),
    )
    ax.set(aspect="equal", title=animal)

# %%
examples = ['01_01', '02_04', '04_02']

# %%
for animal in examples:
    fig = figure(1.75, 1.5)
    ax = sns.heatmap(
        corrs.loc[animal].to_numpy()[g.dendrogram_row.reordered_ind][
            :, g.dendrogram_row.reordered_ind
        ],
        vmin=-1,
        vmax=1,
        cmap="RdBu_r",
        cbar_kws=dict(label="Correlation (rho)"),
    )
    ax.set(
        aspect="equal",
        title=animal,
        xticks=[],
        yticks=[],
        xlabel="Syllable ID",
        ylabel="Syllable ID",
    )
