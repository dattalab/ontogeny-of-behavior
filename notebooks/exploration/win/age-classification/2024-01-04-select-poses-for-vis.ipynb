# %%
import joblib
import matplotlib.pyplot as plt
from toolz import keyfilter
from aging.organization.paths import ValidationPaths
from aging.plotting import figure

# %%
val_paths = ValidationPaths()

# %%
data = joblib.load(val_paths.age_classifier)

# %%
old = keyfilter(lambda k: k[0] == 103, data)

# %%
old_keys = sorted(old)

# %%
figure(1.2, 1)
plt.imshow(old[old_keys[0]][2])
plt.colorbar()

# %%
figure(1.2, 1)
plt.imshow(old[old_keys[1]][55])
plt.colorbar()

# %%
figure(1.2, 1)
plt.imshow(old[old_keys[2]][0])
plt.colorbar()

# %%
figure(1.2, 1)
tmp = old[old_keys[2]][20].copy()
# tmp[tmp < 10] = 0
plt.imshow(tmp)
plt.colorbar()

# %%
young = keyfilter(lambda k: k[0] == 4, data)

# %%
young_keys = sorted(young)

# %%
young_keys
# Out:
# [(4,
#   PosixPath('/n/groups/datta/Dana/Ontogeny/raw_data/Ontogeny_males/4wks_120123/session_20231201080022/proc/results_00.h5')),
#  (4,
#   PosixPath('/n/groups/datta/Dana/Ontogeny/raw_data/Ontogeny_males/4wks_120123/session_20231201095501/proc/results_00.h5')),
#  (4,
#   PosixPath('/n/groups/datta/Dana/Ontogeny/raw_data/Ontogeny_males/4wks_120123/session_20231201125309/proc/results_00.h5')),
#  (4,
#   PosixPath('/n/groups/datta/Dana/Ontogeny/raw_data/Ontogeny_males/4wks_120123/session_20231201125438/proc/results_00.h5')),
#  (4,
#   PosixPath('/n/groups/datta/Dana/Ontogeny/raw_data/Ontogeny_males/4wks_120123/session_20231201130810/proc/results_00.h5'))]

# %%
figure(1.2, 1)
plt.imshow(young[young_keys[0]][0])
plt.colorbar()

# %%
figure(1.2, 1)
plt.imshow(young[young_keys[0]][10])
plt.colorbar()

# %%
figure(1.2, 1)
plt.imshow(young[young_keys[1]][17])
plt.colorbar()

# %%
figure(1.2, 1)
plt.imshow(young[young_keys[2]][17])
plt.colorbar()

# %%
set([k[0] for k in data])
# Out:
# {3,
#  4,
#  5,
#  7,
#  8,
#  9,
#  12,
#  16,
#  20,
#  24,
#  28,
#  32,
#  35,
#  36,
#  40,
#  44,
#  48,
#  52,
#  56,
#  60,
#  64,
#  68,
#  72,
#  78,
#  80,
#  84,
#  90,
#  103}

# %%
mid = keyfilter(lambda k: k[0] == 48, data)
mid_keys = sorted(mid)

# %%
figure(1.2, 1)
plt.imshow(mid[mid_keys[0]][1])
plt.colorbar()

# %%
figure(1.2, 1)
plt.imshow(mid[mid_keys[0]][30])
plt.colorbar()

# %%
figure(1.2, 1)
plt.imshow(mid[mid_keys[1]][20])
plt.colorbar()

# %%
figure(1.2, 1)
plt.imshow(mid[mid_keys[2]][120])
plt.colorbar()

# %%
figure(1.2, 1)
plt.imshow(mid[mid_keys[3]][32])
plt.colorbar()
