# %%
from datetime import datetime
from pathlib import Path
from aging.size_norm.validation import link_results_folder, pca_pose_manifold
from aging.organization.paths import ValidationPaths

# %%
model_path = Path("/home/wg41/groups/win/longtogeny/size_norm/models/bottleneck_param_scan_00/stage_01/56e4e034-c98d-4e77-a79f-c742dd835d70/model.pt")
val_paths = ValidationPaths()
save_path = model_path.parent / "age_classification/transformed_age_classification_poses.p"

# %%
out_folder = val_paths.manifold_pipeline / (datetime.now().strftime(
    "%Y-%m-%d_%H-%M-%S"
) + "_pose_manifold")

# %%
pca_pose_manifold(val_paths.age_classifier, save_path, out_folder)
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# ...

# %%
link_results_folder(out_folder, model_path.parent)

# %% [markdown]
# ## Compute changepoints

# %%
from aging.size_norm.validation import plot_changepoints, plot_changepoint_correlations, compute_changepoints

# %%
pre_cps, post_cpts = compute_changepoints(val_paths.age_classifier, save_path)

# %%
out_folder = val_paths.changepoints_pipeline / (datetime.now().strftime(
    "%Y-%m-%d_%H-%M-%S"
) + "_changepoints")

# %%
plot_changepoints(pre_cps, post_cpts, out_folder)
# Out:
# /n/groups/datta/win/longtogeny/code/aging/plotting.py:103: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   fig.tight_layout()
# /n/groups/datta/win/longtogeny/code/aging/plotting.py:103: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   fig.tight_layout()
# /n/groups/datta/win/longtogeny/code/aging/plotting.py:103: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   fig.tight_layout()
# /n/groups/datta/win/longtogeny/code/aging/plotting.py:103: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   fig.tight_layout()
# ...

# %%
plot_changepoint_correlations(pre_cps, post_cpts, out_folder)
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# ...

# %% [markdown]
# ## Compute dynamics
